# %%
print("Hello Fatima Momin")
# Out:
# Hello Fatima Momin

# %%
2+3
# Out:
# 5

# %%
2-4
# Out:
# -2

# %%
3/9
# Out:
# 0.3333333333333333

# %%
5*2
# Out:
# 10

# %%
a=10

# %%
a
# Out:
# 10

# %%
a=20

# %%
a
# Out:
# 20

# %%
a=10
b=40

# %%
c=a+b

# %%
print(c)
# Out:
# 50

# %%
a+b-c
# Out:
# 0

# %%
print(a-b+c)
# Out:
# 20

# %%
2**2
# Out:
# 4

# %%
2**4
# Out:
# 16

# %%
print(' Done here')
# Out:
#  Done here

# %%
# %pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install matplotlip
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install plotly
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install scipystate
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement scipystate (from versions: none)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: No matching distribution found for scipystate

# %%
# %pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install tensorflow
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement tensorflow (from versions: none)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: No matching distribution found for tensorflow

# %%
# %pip install keras
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install pytorch
# Out:
# ...
#   Using cached pytorch-1.0.2.tar.gz (689 bytes)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
# Failed to build pytorch
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   × Building wheel for pytorch (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [35 lines of output]
#       Traceback (most recent call last):
#         File "c:\Users\Administrator\AppData\Local\Programs\Python\Python313\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 353, in <module>
#           main()
#           ~~~~^^
# ...

# %%
# %pip install streamlite
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement streamlite (from versions: none)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: No matching distribution found for streamlite

# %%
# %pip install pychorn
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement pychorn (from versions: none)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: No matching distribution found for pychorn

# %%
# %pip install catboost
# Out:
# ...
#      ---------------------------------------- 0.0/71.5 MB ? eta -:--:--
#      ---------------------------------------- 0.0/71.5 MB ? eta -:--:--
#      ---------------------------------------- 0.0/71.5 MB ? eta -:--:--
#      ---------------------------------------- 0.3/71.5 MB ? eta -:--:--
#      ---------------------------------------- 0.3/71.5 MB ? eta -:--:--
#      --------------------------------------- 0.5/71.5 MB 568.1 kB/s eta 0:02:06
#      --------------------------------------- 0.5/71.5 MB 568.1 kB/s eta 0:02:06
#      --------------------------------------- 0.5/71.5 MB 568.1 kB/s eta 0:02:06
#      --------------------------------------- 0.5/71.5 MB 568.1 kB/s eta 0:02:06
#      --------------------------------------- 0.5/71.5 MB 568.1 kB/s eta 0:02:06
#      --------------------------------------- 0.5/71.5 MB 568.1 kB/s eta 0:02:06
#      --------------------------------------- 0.5/71.5 MB 568.1 kB/s eta 0:02:06
# ...
